# %%
import pyodbc
import urllib.request
import requests
import pandas as pd
import numpy as np
from io import StringIO

# %%
#target url: https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt
with urllib.request.urlopen("https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt") as url:
    s = url.read()

# %%
n = '\n'
bn = bytes(n,encoding='utf-8')
s.split(bn)

s = str(s,'utf-8')
data = StringIO(s)
df = pd.read_csv(data,sep=",")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-217-bbe10119253b> in <module>
#       1 n = '\n'
#       2 bn = bytes(n,encoding='utf-8')
# ----> 3 s.split(bn)
#       4
#       5 s = str(s,'utf-8')
#
# TypeError: must be str or None, not bytes

# %%
#data = csvToArray('https://www.ncei.noaa.gov/access/services/data/v1?dataset=daily-summaries&dataTypes=WIND_SPEED,TMAX,TMIN,PRCP&stations=USC00047821&startDate=1900-10-01&endDate=2019-11-01&format=csv')

pd.read_csv('https://www.ncei.noaa.gov/access/services/data/v1?dataset=daily-summaries&dataTypes=WIND_SPEED,TMAX,TMIN,PRCP&stations=USC00457180,USC00390043&startDate=1900-10-01&endDate=2019-11-01&format=csv')
# Out:
#            STATION        DATE   PRCP   TMAX   TMIN  WIND_SPEED
# 0      USC00457180  1900-10-01    0.0  117.0   11.0         NaN
# 1      USC00457180  1900-10-02    0.0  122.0   17.0         NaN
# 2      USC00457180  1900-10-03  107.0  106.0   44.0         NaN
# 3      USC00457180  1900-10-04    8.0  111.0   22.0         NaN
# 4      USC00457180  1900-10-05   76.0  100.0   50.0         NaN
# 5      USC00457180  1900-10-06    0.0  100.0    6.0         NaN
# 6      USC00457180  1900-10-07    0.0  161.0    0.0         NaN
# 7      USC00457180  1900-10-08    0.0  200.0   22.0         NaN
# 8      USC00457180  1900-10-09    0.0  183.0    0.0         NaN
# 9      USC00457180  1900-10-10   33.0  133.0   67.0         NaN
# 10     USC00457180  1900-10-11    0.0  167.0   -6.0         NaN
# 11     USC00457180  1900-10-12    0.0  167.0    0.0         NaN
# 12     USC00457180  1900-10-13    0.0  183.0   28.0         NaN
# 13     USC00457180  1900-10-14    0.0  172.0   89.0         NaN
# ...

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LAPTOP-RC2ANL8F\SQLEXPRESS;'
                      'Database=WeatherWars;'
                      'Trusted_Connection=yes;')

# %%
cursor = conn.cursor()

# %%
cursor.execute('SELECT * FROM WeatherWars.dbo.player')

# %%
for row in cursor:
    print(row)
# Out:
# ('o', 'o', '1995-11-15', 'o', '4')
# ('omri', 'easypass', '1995-11-15', 'omrilevia@gmail.com', '4087813509')

# %%
command = 'INSERT INTO WeatherWars.dbo.player VALUES(\'o\',\'o\',\'1995-11-15\',\'o\',\'4\')'

# %%
cursor.execute(command)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-171-31a416c28c4e> in <module>
# ----> 1 cursor.execute(command)
#
# IntegrityError: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__player__66DCF95D68DB09AB'. Cannot insert duplicate key in object 'dbo.player'. The duplicate key value is (o). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")

# %%
cursor.execute('SELECT * FROM WeatherWars.dbo.player')

# %%
for row in cursor:
    print(row)
# Out:
# ('o', 'o', '1995-11-15', 'o', '4')
# ('omri', 'easypass', '1995-11-15', 'omrilevia@gmail.com', '4087813509')
